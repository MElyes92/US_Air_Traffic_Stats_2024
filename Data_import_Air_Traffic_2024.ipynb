# %%
import pandas as pd
import os

# Path to the directory containing CSV files
folder_path = "/content/Flight"

# List to hold individual DataFrames
dataframes = []

# Loop through all CSV files in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith(".csv"):  # Only process CSV files
        file_path = os.path.join(folder_path, file_name)

        # Read the CSV file into a DataFrame
        df1 = pd.read_csv(file_path)

        # Append the DataFrame to the list
        dataframes.append(df1)

# Concatenate all DataFrames into one
df = pd.concat(dataframes, ignore_index=True)

# Display the resulting DataFrame
print(df)
# Out:
#                        FL_DATE OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  \
# 0         6/1/2024 12:00:00 AM                9E             4824.0
# 1         6/1/2024 12:00:00 AM                9E             4830.0
# 2         6/1/2024 12:00:00 AM                9E             4830.0
# 3         6/1/2024 12:00:00 AM                9E             4835.0
# 4         6/1/2024 12:00:00 AM                9E             4874.0
# ...                        ...               ...                ...
# 5297574  2/29/2024 12:00:00 AM                YX             5840.0
# 5297575  2/29/2024 12:00:00 AM                YX             5841.0
# 5297576  2/29/2024 12:00:00 AM                YX             5841.0
# 5297577  2/29/2024 12:00:00 AM                YX             5842.0
# 5297578  2/29/2024 12:00:00 AM                YX             5844.0
#
#          ORIGIN_AIRPORT_ID  ORIGIN_CITY_MARKET_ID ORIGIN ORIGIN_STATE_NM  \
# 0                    11433                  31295    DTW        Michigan
# ...

# %%
df.isnull().sum()
# Out:
# FL_DATE                        0
# OP_UNIQUE_CARRIER              0
# OP_CARRIER_FL_NUM              1
# ORIGIN_AIRPORT_ID              0
# ORIGIN_CITY_MARKET_ID          0
# ORIGIN                         0
# ORIGIN_STATE_NM                0
# DEST_AIRPORT_ID                0
# DEST_CITY_MARKET_ID            0
# DEST                           0
# DEST_STATE_NM                  0
# DEP_TIME                   80062
# DEP_DELAY_NEW              80320
# CANCELLED                      0
# CANCELLATION_CODE        5214328
# AIR_TIME                   97611
# FLIGHTS                   582622
# DISTANCE                       0
# CARRIER_DELAY            4135579
# WEATHER_DELAY            4135579
# NAS_DELAY                4135579
# SECURITY_DELAY           4135579
# LATE_AIRCRAFT_DELAY      4135579
# OP_CARRIER_AIRLINE_ID    4714957
# dtype: int64

# %%
import pandas as pd


# Convert to datetime format
df['FL_DATE'] = pd.to_datetime(df['FL_DATE'], format="%m/%d/%Y %I:%M:%S %p")

# Format the column to the desired format
df['FL_DATE'] = df['FL_DATE'].dt.strftime("%m/%d/%Y")

# Convert format to datetime
df['FL_DATE'] = pd.to_datetime(df['FL_DATE'], format="%m/%d/%Y")

# %%
#df['FL_DATE'] = pd.to_datetime(df['FL_DATE'], format='%m/%d/%Y %I:%M:%S %p')
#df['YEAR'] = pd.to_datetime(df['YEAR'], format='%Y')
#df['MONTH'] = pd.to_datetime(df['MONTH'], format='%m')
#df['DAY_OF_MONTH'] = pd.to_datetime(df['DAY_OF_MONTH'], format='%d')
#df['DAY_OF_WEEK'] = pd.to_datetime(df['DAY_OF_WEEK']).dt.day_name()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5297579 entries, 0 to 5297578
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   FL_DATE                datetime64[ns]
#  1   OP_UNIQUE_CARRIER      object
#  2   OP_CARRIER_FL_NUM      float64
#  3   ORIGIN_AIRPORT_ID      int64
#  4   ORIGIN_CITY_MARKET_ID  int64
#  5   ORIGIN                 object
#  6   ORIGIN_STATE_NM        object
#  7   DEST_AIRPORT_ID        int64
#  8   DEST_CITY_MARKET_ID    int64
#  9   DEST                   object
#  10  DEST_STATE_NM          object
#  11  DEP_TIME               float64
#  12  DEP_DELAY_NEW          float64
#  13  CANCELLED              float64
#  14  CANCELLATION_CODE      object
#  15  AIR_TIME               float64
#  16  FLIGHTS                float64
#  17  DISTANCE               float64
#  18  CARRIER_DELAY          float64
#  19  WEATHER_DELAY          float64
#  20  NAS_DELAY              float64
# ...

# %%
df.head()
# Out:
#      FL_DATE OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0 2024-06-01                9E             4824.0              11433
# 1 2024-06-01                9E             4830.0              11433
# 2 2024-06-01                9E             4830.0              13459
# 3 2024-06-01                9E             4835.0              14524
# 4 2024-06-01                9E             4874.0              11775
#
#    ORIGIN_CITY_MARKET_ID ORIGIN ORIGIN_STATE_NM  DEST_AIRPORT_ID  \
# 0                  31295    DTW        Michigan            11042
# 1                  31295    DTW        Michigan            13459
# 2                  33459    MQT        Michigan            11433
# 3                  34524    RIC        Virginia            12953
# 4                  31775    FSD    South Dakota            13487
#
#    DEST_CITY_MARKET_ID DEST  ... CANCELLATION_CODE  AIR_TIME  FLIGHTS  \
# 0                30647  CLE  ...               NaN      23.0      1.0
# ...

# %%
df.describe()
# Out:
#                              FL_DATE  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# count                        5297579       5.297578e+06       5.297579e+06
# mean   2024-05-19 12:02:54.583295232       2.487307e+03       1.264810e+04
# min              2024-01-01 00:00:00       1.000000e+00       1.013500e+04
# 25%              2024-03-14 00:00:00       1.144000e+03       1.129200e+04
# 50%              2024-05-21 00:00:00       2.208000e+03       1.288900e+04
# 75%              2024-07-26 00:00:00       3.697000e+03       1.402700e+04
# max              2024-09-30 00:00:00       8.819000e+03       1.686900e+04
# std                              NaN       1.646358e+03       1.531815e+03
#
#        ORIGIN_CITY_MARKET_ID  DEST_AIRPORT_ID  DEST_CITY_MARKET_ID  \
# count           5.297579e+06     5.297579e+06         5.297579e+06
# mean            3.173371e+04     1.264810e+04         3.173372e+04
# min             3.007000e+04     1.013500e+04         3.007000e+04
# ...

# %%
df.to_csv('flights24.csv', index=False)
